# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("cancer.csv")
data.tail()
# Out:
#     age  cancer_patient_or_not
# 35   61                      1
# 36   53                      1
# 37   49                      1
# 38   23                      0
# 39   55                      1

# %%
plt.scatter(data.age, data.cancer_patient_or_not)

# %%
x = data[["age"]]
x
# Out:
#     age
# 0    25
# 1    38
# 2    34
# 3    30
# 4    45
# 5     4
# 6    75
# 7    67
# 8    51
# 9    10
# 10   12
# 11    2
# 12   59
# 13   64
# 14   39
# 15   41
# 16   40
# 17    8
# 18    5
# 19   56
# 20   54
# 21   39
# 22   27
# 23   22
# 24   21
# 25   47
# 26   52
# 27   18
# 28   70
# 29   71
# 30   44
# 31    9
# 32   19
# 33   59
# 34   69
# 35   61
# 36   53
# 37   49
# 38   23
# 39   55

# %%
y = data["cancer_patient_or_not"]
y
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
# 5     0
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    0
# 15    0
# 16    1
# 17    0
# 18    0
# 19    0
# 20    1
# 21    0
# 22    0
# 23    0
# 24    1
# 25    0
# 26    1
# 27    0
# 28    0
# 29    1
# 30    1
# 31    0
# 32    0
# 33    1
# 34    1
# 35    1
# 36    1
# 37    1
# 38    0
# 39    1
# Name: cancer_patient_or_not, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
len(x_train)
# Out:
# 32

# %%
len(x_test)
# Out:
# 8

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 1, 1, 0, 1, 1, 0])

# %%
x_test
# Out:
#     age
# 22   27
# 20   54
# 25   47
# 4    45
# 10   12
# 15   41
# 28   70
# 11    2

# %%
y_test
# Out:
# 22    0
# 20    1
# 25    0
# 4     1
# 10    0
# 15    0
# 28    0
# 11    0
# Name: cancer_patient_or_not, dtype: int64

# %%
model.score(x_test, y_test)
# Out:
# 0.625

# %%
age = [[3]]
model.predict(age)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
