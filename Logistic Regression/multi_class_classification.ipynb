# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("hours_studied.csv")
data
# Out:
#     Hours_Studies Performance
# 0               1        Poor
# 1               2        Poor
# 2               3     Average
# 3               4     Average
# 4               5        Good
# 5               6        Good
# 6               7   Excellent
# 7               8   Excellent
# 8               2        Poor
# 9               3     Average
# 10              5        Good
# 11              7   Excellent
# 12              4     Average
# 13              6        Good
# 14              8   Excellent
# 15              1        Poor

# %%
plt.scatter(data.Hours_Studies,data.Performance)
plt.xlabel("Hours Studies")
plt.ylabel("Performance")
plt.title("Student Performance Dataset")
plt.show()

# %%
x = data[["Hours_Studies"]]
x.head()
# Out:
#    Hours_Studies
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
y = data["Performance"]

y.head()
# Out:
# 0       Poor
# 1       Poor
# 2    Average
# 3    Average
# 4       Good
# Name: Performance, dtype: str

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=0,
)

# %%
len(x_train)
# Out:
# 12

# %%
len(x_test)
# Out:
# 4

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(x_test)
predictions
# Out:
# array(['Poor', 'Excellent', 'Poor', 'Average'], dtype=object)

# %%
result = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": predictions
})
result
# Out:
#       Actual  Predicted
# 0       Poor       Poor
# 1  Excellent  Excellent
# 2       Poor       Poor
# 3    Average    Average

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
hours = [[6]]
model.predict(hours)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Good'], dtype=object)

# %%
model.predict_proba([[6]])
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[0.1458681 , 0.28338286, 0.5661607 , 0.00458834]])
