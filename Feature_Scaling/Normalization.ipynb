# %%
import numpy as np
data = np.array([
    [26,50000],
    [29,70000],
    [34,55000],
    [31,41000]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)
scaled_data
# Out:
# array([[0.        , 0.31034483],
#        [0.375     , 1.        ],
#        [1.        , 0.48275862],
#        [0.625     , 0.        ]])
